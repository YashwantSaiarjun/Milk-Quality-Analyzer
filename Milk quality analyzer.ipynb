# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Milk Grading .csv.")

# %%
data.head(10)
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour  Grade
# 0  6.6          35      1     0     1          0     254    1.0
# 1  6.6          36      0     1     0          1     253    1.0
# 2  8.5          70      1     1     1          1     246    0.0
# 3  9.5          34      1     1     0          1     255    0.0
# 4  6.6          37      0     0     0          0     255    0.5
# 5  6.6          37      1     1     1          1     255    1.0
# 6  5.5          45      1     0     1          1     250    0.0
# 7  4.5          60      0     1     1          1     250    0.0
# 8  8.1          66      1     0     1          1     255    0.0
# 9  6.7          45      1     1     0          0     247    0.5

# %% [markdown]
# ## Description

# %% [markdown]
# 1. ph - The pH level of milk is around 6.5 to 6.7 and since it falls below the neutral pH of 7.0 we can say that it is    slightly acidic.
#
# 2. Receive milk at 40°F or less. Milk delivered at the proper temperature will stay fresher longer. Cold temperatures slow or prevent the growth of the harmless bacteria that cause milk spoilage and also reduce the likelihood of other flavor defects.
#
# 3. Taste, Odor, Fat - 1 yes, 0- no;
#
# 4. The breaking up of the fat globules causes them to scatter a greater amount of light and gives the milk a more opaque appearance (1-yes 0-no)
#
# 5. color (in white scale)

# %%
data.shape
# Out:
# (1059, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pH          1059 non-null   float64
#  1   Temprature  1059 non-null   int64
#  2   Taste       1059 non-null   int64
#  3   Odor        1059 non-null   int64
#  4   Fat         1059 non-null   int64
#  5   Turbidity   1059 non-null   int64
#  6   Colour      1059 non-null   int64
#  7   Grade       1059 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 66.3 KB

# %%
data.describe()
# Out:
#                 pH   Temprature        Taste         Odor         Fat   \
# count  1059.000000  1059.000000  1059.000000  1059.000000  1059.000000
# mean      6.630123    44.226629     0.546742     0.432483     0.671388
# std       1.399679    10.098364     0.498046     0.495655     0.469930
# min       3.000000    34.000000     0.000000     0.000000     0.000000
# 25%       6.500000    38.000000     0.000000     0.000000     0.000000
# 50%       6.700000    41.000000     1.000000     0.000000     1.000000
# 75%       6.800000    45.000000     1.000000     1.000000     1.000000
# max       9.500000    90.000000     1.000000     1.000000     1.000000
#
#          Turbidity       Colour        Grade
# count  1059.000000  1059.000000  1059.000000
# mean      0.491029   251.840415     0.418319
# std       0.500156     4.307424     0.393934
# min       0.000000   240.000000     0.000000
# 25%       0.000000   250.000000     0.000000
# 50%       0.000000   255.000000     0.500000
# ...

# %% [markdown]
# ## EDA

# %%
# no of values in color attribute
a=data['Colour'].value_counts()
df = pd.DataFrame(data=a)
df
# Out:
#      Colour
# 255     628
# 250     146
# 245     115
# 247      48
# 246      44
# 240      32
# 248      23
# 253      22
# 254       1

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Colour", data=data)

# %%
data["Grade"].value_counts().plot.bar(title = "Milk in Each Grade",color='purple')
# Out:
# <AxesSubplot:title={'center':'Milk in Each Grade'}>

# %% [markdown]
# ### Ph vs grade

# %%
sns.jointplot(x='pH',y='Grade',data=data,color='green')

# %% [markdown]
# ## Temperature vs Grade

# %%
sns.jointplot(x='Temprature',y='Grade',data=data,color='red')

# %% [markdown]
# ## Taste vs Grade

# %%
sns.countplot(x='Taste',data=data)  
plt.show()

# %%
sns.jointplot(x='Taste',y='Grade',data=data,color='orange')

# %% [markdown]
# ## Odor vs Grade

# %%
sns.countplot(x='Odor',data=data)  
plt.show()

# %%
sns.jointplot(x='Odor',y='Grade',data=data,color='blue')

# %% [markdown]
# ## Heatmap

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.hist(data['Temprature'])
plt.title("Temperature ranges of milk samples",fontsize = 40)
 
# Show plot
plt.show()

# %%
plt.hist(data['pH'],color='violet',bins=7)
plt.title("pH ranges of milk sample",fontsize = 40)
plt.show()

# %%
sns.scatterplot(x = "pH", y = "Temprature", data = data)
plt.title("pH vs Temprature",fontsize = 40)
# Out:
# Text(0.5, 1.0, 'pH vs Temprature')

# %%
sns.boxplot(data['pH'])
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data['Temprature'])
plt.show()
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
uv=np.percentile(data.Temprature,[99])[0]
uv
# Out:
# 90.0

# %%
pd.crosstab(index = data["Taste"],columns = data["Grade"]).plot(kind='bar',
 figsize=(10, 6),alpha=0.5,rot=0,stacked=True,title="Taste vs Grade")
# Out:
# <AxesSubplot:title={'center':'Taste vs Grade'}, xlabel='Taste'>

# %%
pd.crosstab(index = data["Odor"],columns = data["Grade"]).plot(kind='bar',
 figsize=(10, 6),alpha=0.5,rot=0,stacked=True,title="Odor vs Grade")
# Out:
# <AxesSubplot:title={'center':'Odor vs Grade'}, xlabel='Odor'>

# %%
pd.crosstab(index = data["Turbidity"],columns = data["Grade"]).plot(kind='bar',
 figsize=(10, 6),alpha=0.5,rot=0,stacked=True,title="Taste vs Grade")
# Out:
# <AxesSubplot:title={'center':'Taste vs Grade'}, xlabel='Turbidity'>

# %% [markdown]
# ## Overall Data visualization for count of values in each column

# %%
plt.rcParams['figure.figsize'] = (10,4) 
#For each milk column, plot it in a bar graph
for column in data.columns:
    plt.figure() #Get the figure so it will let me plot multiple
    data[column].value_counts().plot.bar(title = column,color='gold')

# %%
data["Grade"].replace({0:'Bad',0.5:'Moderate',1:'Good'}, inplace=True)
data.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour     Grade
# 0  6.6          35      1     0     1          0     254      Good
# 1  6.6          36      0     1     0          1     253      Good
# 2  8.5          70      1     1     1          1     246       Bad
# 3  9.5          34      1     1     0          1     255       Bad
# 4  6.6          37      0     0     0          0     255  Moderate

# %% [markdown]
# ## Machine Learning

# %%
Y = data['Grade'].values
print(Y)
# Out:
# ['Good' 'Good' 'Bad' ... 'Bad' 'Good' 'Bad']

# %%
X = data.drop(['Grade'],axis=1)
print(X)
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour
# 0     6.6          35      1     0     1          0     254
# 1     6.6          36      0     1     0          1     253
# 2     8.5          70      1     1     1          1     246
# 3     9.5          34      1     1     0          1     255
# 4     6.6          37      0     0     0          0     255
# ...   ...         ...    ...   ...   ...        ...     ...
# 1054  6.7          45      1     1     0          0     247
# 1055  6.7          38      1     0     1          0     255
# 1056  3.0          40      1     1     1          1     255
# 1057  6.8          43      1     0     1          0     250
# 1058  8.6          55      0     1     1          1     255
#
# [1059 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
print(x_train.shape)
# Out:
# (741, 7)

# %%
print(x_test.shape)
# Out:
# (318, 7)

# %%
print(y_train.shape)
# Out:
# (741,)

# %%
print(y_test.shape)
# Out:
# (318,)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(x_test)

# %%
acc=accuracy_score(y_test, y_pred)
print("Accuracy : %.2f"%acc)
# Out:
# Accuracy : 0.99

# %%
inputt=[float(x) for x in "6.6 37 1 1 1 1 255".split(' ')]
final=[np.array(inputt)]

b = model.predict(final)
print(b)
# Out:
# ['Good']

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Good', 'Bad', 'Moderate', 'Bad', 'Good', 'Moderate', 'Bad',
#        'Good', 'Good', 'Moderate', 'Bad', 'Good', 'Moderate', 'Moderate',
#        'Good', 'Moderate', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad',
#        'Moderate', 'Good', 'Good', 'Bad', 'Good', 'Good', 'Bad',
#        'Moderate', 'Good', 'Bad', 'Bad', 'Moderate', 'Good', 'Good',
#        'Bad', 'Moderate', 'Good', 'Bad', 'Good', 'Moderate', 'Good',
#        'Bad', 'Moderate', 'Bad', 'Good', 'Bad', 'Moderate', 'Bad', 'Good',
#        'Moderate', 'Moderate', 'Moderate', 'Bad', 'Moderate', 'Moderate',
#        'Bad', 'Moderate', 'Bad', 'Moderate', 'Bad', 'Moderate', 'Good',
#        'Bad', 'Moderate', 'Bad', 'Moderate', 'Moderate', 'Good', 'Good',
#        'Moderate', 'Moderate', 'Good', 'Moderate', 'Moderate', 'Moderate',
#        'Bad', 'Good', 'Moderate', 'Bad', 'Moderate', 'Moderate', 'Bad',
#        'Moderate', 'Moderate', 'Good', 'Bad', 'Good', 'Bad', 'Moderate',
# ...

# %%
y_test
# Out:
# array(['Good', 'Bad', 'Moderate', 'Bad', 'Good', 'Moderate', 'Bad',
#        'Good', 'Good', 'Moderate', 'Bad', 'Good', 'Moderate', 'Moderate',
#        'Good', 'Bad', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad',
#        'Moderate', 'Good', 'Good', 'Bad', 'Good', 'Good', 'Bad',
#        'Moderate', 'Good', 'Bad', 'Bad', 'Moderate', 'Good', 'Good',
#        'Bad', 'Good', 'Good', 'Bad', 'Good', 'Moderate', 'Good', 'Bad',
#        'Moderate', 'Bad', 'Good', 'Bad', 'Moderate', 'Bad', 'Good',
#        'Moderate', 'Moderate', 'Moderate', 'Bad', 'Moderate', 'Moderate',
#        'Bad', 'Moderate', 'Bad', 'Moderate', 'Bad', 'Moderate', 'Good',
#        'Bad', 'Moderate', 'Bad', 'Moderate', 'Moderate', 'Good', 'Good',
#        'Moderate', 'Moderate', 'Good', 'Moderate', 'Moderate', 'Moderate',
#        'Bad', 'Good', 'Moderate', 'Bad', 'Moderate', 'Moderate', 'Bad',
#        'Moderate', 'Moderate', 'Good', 'Bad', 'Bad', 'Bad', 'Moderate',
# ...

# %%
acc=accuracy_score(y_test, y_pred)
print("Accuracy : %.2f"%acc)
# Out:
# Accuracy : 0.99

# %%
import pickle
pickle.dump(clf,open('milkquality.pkl','wb'))
model=pickle.load(open('milkquality.pkl','rb'))
